# %%
import wandb
import pandas as pd

# %%
entity = "evangeorgerex"
project = "fwal"

# %%
def fetch_runs(entity, project, sweep_ids):
    api = wandb.Api()
    runs_data = []

    for sweep_id in sweep_ids:
        sweep_runs = api.sweep(f"{entity}/{project}/{sweep_id}").runs
        for run in sweep_runs:
            # Check if the run's state is 'finished'
            if run.state == "finished":
                run_name = run.id
                dataset_name = run.config.get("dataset", "Unknown")
                if dataset_name in ["poly_binarised_decimalised_mod10_synth", "simple_trig_synth", "Unknown"]:
                    continue
                
                if run.config.get("as_MLP_baseline", False):
                    model_name = "MLP_same_capacity"
                else:
                    model_name = run.config.get("model", "Unknown")
                    if model_name == "fwal":
                        model_name = "F-Act"
                        
                        
                    # if run.config.get("hierarchical", False):
                    #     model_name = "F-Act hierarchical"
                    #     if run.config.get("share_mask", False):
                    #         model_name = "F-Act hierarchical shared"
                    #         if run.config.get("sigmoid_loss", False):
                    #             model_name = "F-Act hierarchical shared L_sig"
                    # if sweep_id == "x9s9n05b":
                    #     model_name = "F-Act hierarchical TTI (old)"
                    # if sweep_id in ["9npryg91", "7i2o46ri"]:
                    #     model_name = "F-Act hierarchical TTI"
                run_data = {
                    "model": model_name,  # Assuming model name is stored in 'model_name'
                    "run_name":run_name,
                    "sweep_id": sweep_id,
                    "dataset": dataset_name,  # Assuming dataset name is stored in 'dataset_name'
                    "seed": run.config.get("seed_model_init", None),
                    "bestmodel_train/F1_weighted": run.summary.get("bestmodel_train/F1_weighted", float('nan')),
                    "bestmodel_valid/F1_weighted": run.summary.get("bestmodel_valid/F1_weighted", float('nan')),
                    "bestmodel_test/F1_weighted": run.summary.get("bestmodel_test/F1_weighted", float('nan')),
                }
                
                
                # Specific hyperparameters
                if model_name == "lasso":
                    run_data["lasso_C"] = run.config.get("lasso_C")
                    run_data["lasso_l1_ratio"] = run.config.get("lasso_l1_ratio")
                elif model_name == "rf":
                    run_data["rf_max_depth"] = run.config.get("rf_max_depth")
                elif model_name in ["cae", "supervised_cae"]:
                    run_data["CAE_neurons_ratio"] = run.config.get("CAE_neurons_ratio")
                elif model_name == "F-Act hierarchical TTI":
                    run_data["sparsity_regularizer_hyperparam"] = run.config.get("sparsity_regularizer_hyperparam")
                elif model_name == "F-Act hierarchical TTI (old)":
                    run_data["sparsity_regularizer_hyperparam"] = run.config.get("sparsity_regularizer_hyperparam")
                elif model_name == "F-Act":
                    if sweep_id in ['unbglcvv']:
                        run_data['dropout'] = run.config.get("dropout_rate")
                        run_data["num_hidden"] = run.config.get("num_hidden")
                    elif sweep_id in ['yg8ursys']:
                        run_data['dropout'] = run.config.get("dropout_rate")
                        run_data["num_hidden"] = 4
                    elif sweep_id in ["bga4xu49", "4p4opie9"]:
                        run_data['dropout'] = 0.2
                        run_data["num_hidden"] = run.config.get("num_hidden")
                    else:
                        # sweep_id == "7i2o46ri":
                        run_data['dropout'] = 0.0
                        run_data["num_hidden"] = 4
                    run_data["lr"] = run.config.get("lr")
                    run_data["sparsity_regularizer_hyperparam"] = run.config.get("sparsity_regularizer_hyperparam")
                elif model_name == "xgboost":
                    run_data["xgb_eta"] = run.config.get("xgb_eta")
                    run_data["xgb_max_depth"] = run.config.get("xgb_max_depth")
                elif model_name in ["MLP_same_capacity", 'SEFS']:
                    run_data["lr"] = run.config.get("lr")
                    run_data["num_hidden"] = run.config.get("num_hidden")
                    
                    
                runs_data.append(run_data)

    return runs_data


def get_best_runs_new(runs_data, hyperparams):
    df = pd.DataFrame(runs_data)

    # Step 1: Group by 'dataset', hyperparameters, and 'seed'. Select the row with the maximum 'bestmodel_valid/F1_weighted' score for each seed.
    max_per_seed = df.groupby(['dataset', 'seed'] + hyperparams).agg({
        'bestmodel_train/F1_weighted': 'max',
        'bestmodel_valid/F1_weighted': 'max',
        'bestmodel_test/F1_weighted': 'max'
    }).reset_index()

    # Step 2: Group by 'dataset' and hyperparameters again, and calculate the mean of the scores across seeds.
    mean_across_seeds = max_per_seed.groupby(['dataset'] + hyperparams).agg({
        'bestmodel_train/F1_weighted': 'mean',
        'bestmodel_valid/F1_weighted': 'mean',
        'bestmodel_test/F1_weighted': 'mean'
    }).reset_index()

    # Step 3: For each 'dataset', find the hyperparameters that lead to the highest average 'bestmodel_valid/F1_weighted'
    optimal_params = mean_across_seeds.loc[mean_across_seeds.groupby('dataset')['bestmodel_valid/F1_weighted'].idxmax()]

    # Step 4: Merge the optimal parameters back to the original dataframe to get the corresponding 'run_name's
    best_runs = pd.merge(
        optimal_params[['dataset'] + hyperparams],
        df,
        on=['dataset'] + hyperparams,
        how='inner'
    ).drop_duplicates(subset=['dataset', 'seed'] + hyperparams)

    # Select only the relevant columns, ensuring to include 'run_name' and other relevant metrics.
    best_run_names = best_runs[['dataset', 'run_name', 'seed', 'sweep_id'] + hyperparams + ['bestmodel_valid/F1_weighted']]
    return best_run_names

def get_best_runs(runs_data, hyperparams):

    df = pd.DataFrame(runs_data)

    # Step 1: Group by 'dataset', 'lasso_C', 'lasso_l1_ratio', and calculate the mean of the F1 scores across seeds.
    grouped = df.groupby(['dataset'] + hyperparams).agg({
        'bestmodel_train/F1_weighted': 'mean',
        'bestmodel_valid/F1_weighted': 'mean',
        'bestmodel_test/F1_weighted': 'mean'
    }).reset_index()

    # Step 2: For each 'dataset', find the hyperparameters that lead to the highest average 'bestmodel_valid/F1_weighted'
    optimal_params = grouped.loc[grouped.groupby('dataset')['bestmodel_valid/F1_weighted'].idxmax()]

    # Print optimal hyperparameters for each dataset
    # print(optimal_params[['dataset', 'lasso_C', 'lasso_l1_ratio', 'bestmodel_valid/F1_weighted']])

    # Step 3: Merge the optimal parameters back to the original dataframe to get the corresponding 'run_name's
    best_runs = pd.merge(
        optimal_params[['dataset'] + hyperparams],
        df,
        on=['dataset'] + hyperparams,
        how='inner'
    )

    # Select only the relevant columns
    best_run_names = best_runs[['dataset', 'run_name', 'seed', 'sweep_id'] + hyperparams +['bestmodel_valid/F1_weighted'] +  ['bestmodel_test/F1_weighted']]
    return best_run_names

def print_run_ids(best_runs):
    output = ''.join(['- '+rn+'\n' for rn in best_runs['run_name'].to_list()])
    print(output)

# %% [markdown]
# # Lasso

# %%
lasso_sweep_ids = [
    'rdvu3fg8', # everything except finance
    'xpxe64ee', # finance
]

lasso_hyperparameters = ['lasso_C', 'lasso_l1_ratio']

# %%
runs_data = fetch_runs(entity, project, lasso_sweep_ids)
best_run_names_lasso = get_best_runs(runs_data, lasso_hyperparameters)

# %%
best_run_names_lasso
# Out:
#                              dataset  run_name  seed  sweep_id  lasso_C  \
# 0                             COIL20  2j5c9lxu     2  rdvu3fg8       10
# 1                             COIL20  k88mir2w     1  rdvu3fg8       10
# 2                             COIL20  dwxmsim1     0  rdvu3fg8       10
# 3                             Isolet  gt7tyeln     2  rdvu3fg8      100
# 4                             Isolet  70kvvbze     1  rdvu3fg8      100
# 5                             Isolet  2ptd0x5l     0  rdvu3fg8      100
# 6                               PBMC  wns0vfsv     2  rdvu3fg8       10
# 7                               PBMC  pf3zov6p     1  rdvu3fg8       10
# 8                               PBMC  tfcohywp     0  rdvu3fg8       10
# 9                               USPS  sg718c2e     2  rdvu3fg8       10
# 10                              USPS  xceejtd2     1  rdvu3fg8       10
# 11                              USPS  ol6n5ujj     0  rdvu3fg8       10
# 12                           finance  vf369m2r     2  xpxe64ee       10
# 13                           finance  qj04zf76     0  xpxe64ee       10
# 14                           finance  rvzko54o     1  xpxe64ee       10
# 15                           madelon  wfz51c2g     2  rdvu3fg8       10
# 16                           madelon  u8ir7re8     1  rdvu3fg8       10
# 17                           madelon  umceu31l     0  rdvu3fg8       10
# 18                      mice_protein  bkbz6gaj     2  rdvu3fg8      100
# 19                      mice_protein  yugvcdf8     1  rdvu3fg8      100
# 20                      mice_protein  uso6laas     0  rdvu3fg8      100
# 21  poly_binarised_decimalised_synth  h0oo4eyt     2  rdvu3fg8      100
# 22  poly_binarised_decimalised_synth  90w4sgar     1  rdvu3fg8      100
# 23  poly_binarised_decimalised_synth  ls7yxzfh     0  rdvu3fg8      100
#
#     lasso_l1_ratio  bestmodel_valid/F1_weighted
# 0             0.50                     0.982551
# 1             0.50                     0.982551
# 2             0.50                     0.982551
# 3             0.25                     0.947942
# 4             0.25                     0.947942
# 5             0.25                     0.947942
# 6             0.00                     0.873614
# 7             0.00                     0.873614
# 8             0.00                     0.873614
# 9             0.75                     0.934612
# 10            0.75                     0.934606
# 11            0.75                     0.934055
# 12            0.50                     0.595040
# 13            0.50                     0.595040
# 14            0.50                     0.595040
# 15            0.00                     0.548075
# 16            0.00                     0.548075
# 17            0.00                     0.548075
# 18            0.00                     0.962885
# 19            0.00                     0.949134
# 20            0.00                     0.981520
# 21            0.50                     0.504205
# 22            0.50                     0.501956
# 23            0.50                     0.501919

# %%
print_run_ids(best_run_names_lasso)
# Out:
# - 2j5c9lxu
# - k88mir2w
# - dwxmsim1
# - gt7tyeln
# - 70kvvbze
# - 2ptd0x5l
# - wns0vfsv
# - pf3zov6p
# - tfcohywp
# - sg718c2e
# - xceejtd2
# - ol6n5ujj
# - vf369m2r
# - qj04zf76
# - rvzko54o
# - wfz51c2g
# - u8ir7re8
# - umceu31l
# - bkbz6gaj
# - yugvcdf8
# - uso6laas
# - h0oo4eyt
# - 90w4sgar
# - ls7yxzfh

# %% [markdown]
# # RF

# %%
rf_sweep_ids = [
    # "22eckaxx", # rf baseline
    # "gty91unf", # rf baseline
    "4upk4xrk", # RF finance
    'l102r3et', # PBMC  
]
rf_hyperparameters = ['rf_max_depth']

# %%
rf_runs_data = fetch_runs(entity, project, rf_sweep_ids)
best_run_names_rf = get_best_runs(rf_runs_data, rf_hyperparameters)

# %%
best_run_names_rf
# Out:
#                              dataset  run_name  seed  sweep_id  rf_max_depth  \
# 0                             COIL20  9on5gumd     2  l102r3et             7
# 1                             COIL20  bik140ln     1  l102r3et             7
# 2                             COIL20  kbdmric0     0  l102r3et             7
# 3                             Isolet  azfgf16o     2  l102r3et             7
# 4                             Isolet  wfnwq2bf     1  l102r3et             7
# 5                             Isolet  a0o0wjqb     0  l102r3et             7
# 6                               PBMC  gazly416     2  l102r3et             7
# 7                               PBMC  wdm15edn     1  l102r3et             7
# 8                               PBMC  l6o39cmv     0  l102r3et             7
# 9                               USPS  klbot3sc     2  l102r3et             7
# 10                              USPS  72ooqt3p     1  l102r3et             7
# 11                              USPS  u1wd0lw7     0  l102r3et             7
# 12                           finance  o6s1ms09     2  4upk4xrk             7
# 13                           finance  zq7pcumg     1  4upk4xrk             7
# 14                           finance  n2wqtr1t     0  4upk4xrk             7
# 15                           madelon  lxdmwbh9     2  l102r3et             7
# 16                           madelon  0achv76s     1  l102r3et             7
# 17                           madelon  oht38v7i     0  l102r3et             7
# 18                      mice_protein  rkv79ddl     2  l102r3et             7
# 19                      mice_protein  c7ow7eai     1  l102r3et             7
# 20                      mice_protein  vpyra7bg     0  l102r3et             7
# 21  poly_binarised_decimalised_synth  o6u8t6sh     2  l102r3et             7
# 22  poly_binarised_decimalised_synth  3frw0uoc     0  l102r3et             7
# 23  poly_binarised_decimalised_synth  x4cnxp9u     1  l102r3et             7
#
#     bestmodel_valid/F1_weighted
# 0                           NaN
# 1                      0.967801
# 2                      0.971608
# 3                      0.918252
# 4                      0.923720
# 5                      0.922599
# 6                      0.870738
# 7                      0.870596
# 8                      0.868228
# 9                      0.940395
# 10                     0.939917
# 11                     0.940970
# 12                     0.593814
# 13                     0.603037
# 14                     0.605256
# 15                     0.682341
# 16                     0.702985
# 17                          NaN
# 18                     0.981443
# 19                     0.972247
# 20                          NaN
# 21                     0.505537
# 22                     0.505640
# 23                     0.507746

# %%
print_run_ids(best_run_names_rf)
# Out:
# - 9on5gumd
# - bik140ln
# - kbdmric0
# - azfgf16o
# - wfnwq2bf
# - a0o0wjqb
# - gazly416
# - wdm15edn
# - l6o39cmv
# - klbot3sc
# - 72ooqt3p
# - u1wd0lw7
# - o6s1ms09
# - zq7pcumg
# - n2wqtr1t
# - lxdmwbh9
# - 0achv76s
# - oht38v7i
# - rkv79ddl
# - c7ow7eai
# - vpyra7bg
# - o6u8t6sh
# - 3frw0uoc
# - x4cnxp9u

# %% [markdown]
# # XGBoost

# %%
xgb_sweep_ids = [
    'yr11wqmg', # everything
]

xgb_hyperparameters = ['xgb_eta', 'xgb_max_depth']

# %%
runs_data_xgb = fetch_runs(entity, project, xgb_sweep_ids)
best_run_names_xgb = get_best_runs(runs_data_xgb, xgb_hyperparameters)

# %%
best_run_names_xgb
# Out:
#                              dataset  run_name  seed  sweep_id  xgb_eta  \
# 0                             COIL20  xgzcuu37     2  yr11wqmg      0.1
# 1                             COIL20  dnsshn1b     1  yr11wqmg      0.1
# 2                             COIL20  o88hpkso     0  yr11wqmg      0.1
# 3                             Isolet  wai78tkf     2  yr11wqmg      0.1
# 4                             Isolet  mx3xpyr0     1  yr11wqmg      0.1
# 5                             Isolet  hn9uwhoq     0  yr11wqmg      0.1
# 6                               PBMC  j3q3ue8i     2  yr11wqmg      0.3
# 7                               PBMC  6hpzi11o     1  yr11wqmg      0.3
# 8                               PBMC  qjkk5v8v     0  yr11wqmg      0.3
# 9                               USPS  0tni6ygc     2  yr11wqmg      0.3
# 10                              USPS  e8b50yxl     1  yr11wqmg      0.3
# 11                              USPS  9xvjwfgt     0  yr11wqmg      0.3
# 12                           finance  knse2dro     2  yr11wqmg      0.5
# 13                           finance  xtun7bzd     1  yr11wqmg      0.5
# 14                           finance  ou92939j     0  yr11wqmg      0.5
# 15                           madelon  jl2vveq2     2  yr11wqmg      0.1
# 16                           madelon  rzg0omcq     1  yr11wqmg      0.1
# 17                           madelon  ld6x4ag6     0  yr11wqmg      0.1
# 18                      mice_protein  92d7rxam     2  yr11wqmg      0.3
# 19                      mice_protein  zsf4ypb2     1  yr11wqmg      0.3
# 20                      mice_protein  qkznq7x3     0  yr11wqmg      0.3
# 21  poly_binarised_decimalised_synth  lbp74wl7     2  yr11wqmg      0.1
# 22  poly_binarised_decimalised_synth  n19mv06e     1  yr11wqmg      0.1
# 23  poly_binarised_decimalised_synth  1mijbx36     0  yr11wqmg      0.1
#
#     xgb_max_depth  bestmodel_valid/F1_weighted
# 0               6                     0.985390
# 1               6                     0.985390
# 2               6                     0.985390
# 3               9                     0.902887
# 4               9                     0.902887
# 5               9                     0.902887
# 6               3                     0.898703
# 7               3                     0.898703
# 8               3                     0.898703
# 9               3                     0.968251
# 10              3                     0.968251
# 11              3                     0.968251
# 12              6                     0.634798
# 13              6                     0.634798
# 14              6                     0.634798
# 15              6                     0.807590
# 16              6                     0.807590
# 17              6                     0.807590
# 18              3                     0.986101
# 19              3                     0.962812
# 20              3                     0.986114
# 21              9                     0.504693
# 22              9                     0.504693
# 23              9                     0.504693

# %%
print_run_ids(best_run_names_xgb)
# Out:
# - xgzcuu37
# - dnsshn1b
# - o88hpkso
# - wai78tkf
# - mx3xpyr0
# - hn9uwhoq
# - j3q3ue8i
# - 6hpzi11o
# - qjkk5v8v
# - 0tni6ygc
# - e8b50yxl
# - 9xvjwfgt
# - knse2dro
# - xtun7bzd
# - ou92939j
# - jl2vveq2
# - rzg0omcq
# - ld6x4ag6
# - 92d7rxam
# - zsf4ypb2
# - qkznq7x3
# - lbp74wl7
# - n19mv06e
# - 1mijbx36

# %% [markdown]
# # MLP

# %%
MLP_sweep_ids = [
    's5m2sqsv', # everything
]

MLP_hyperparameters = ['lr', 'num_hidden']

# %%
runs_data_MLP = fetch_runs(entity, project, MLP_sweep_ids)
best_run_names_MLP = get_best_runs(runs_data_MLP, MLP_hyperparameters)

# %%
best_run_names_MLP
# Out:
#                              dataset  run_name  seed  sweep_id      lr  \
# 0                             COIL20  srbvb01a     2  s5m2sqsv  0.0010
# 1                             COIL20  oekx63p8     1  s5m2sqsv  0.0010
# 2                             COIL20  alprfdqq     0  s5m2sqsv  0.0010
# 3                             Isolet  d8w94wnf     2  s5m2sqsv  0.0010
# 4                             Isolet  76lre0vu     1  s5m2sqsv  0.0010
# 5                             Isolet  4z1wjp9y     0  s5m2sqsv  0.0010
# 6                               PBMC  kyc5dopk     2  s5m2sqsv  0.0010
# 7                               PBMC  x3nb16bc     1  s5m2sqsv  0.0010
# 8                               PBMC  c9xudzv0     0  s5m2sqsv  0.0010
# 9                               USPS  mp8v0qtq     1  s5m2sqsv  0.0010
# 10                              USPS  7oe60sig     2  s5m2sqsv  0.0010
# 11                              USPS  ccl9a7eu     0  s5m2sqsv  0.0010
# 12                           finance  rc1n4qi1     2  s5m2sqsv  0.0010
# 13                           finance  invvzj6h     1  s5m2sqsv  0.0010
# 14                           finance  2fqxsay5     0  s5m2sqsv  0.0010
# 15                           madelon  hpty0m0z     2  s5m2sqsv  0.0010
# 16                           madelon  vqc4hdpr     1  s5m2sqsv  0.0010
# 17                           madelon  3ocbbqie     0  s5m2sqsv  0.0010
# 18                      mice_protein  nc206z8l     2  s5m2sqsv  0.0001
# 19                      mice_protein  hii8gyar     1  s5m2sqsv  0.0001
# 20                      mice_protein  013sp4et     0  s5m2sqsv  0.0001
# 21  poly_binarised_decimalised_synth  j7trhmgk     2  s5m2sqsv  0.0001
# 22  poly_binarised_decimalised_synth  l8anh9u4     1  s5m2sqsv  0.0001
# 23  poly_binarised_decimalised_synth  sr87k9n5     0  s5m2sqsv  0.0001
#
#     num_hidden  bestmodel_valid/F1_weighted
# 0            1                     0.993047
# 1            1                     0.992923
# 2            1                     0.993025
# 3            2                     0.941667
# 4            2                     0.938385
# 5            2                     0.954844
# 6            4                     0.894113
# 7            4                     0.903739
# 8            4                     0.898891
# 9            1                     0.972011
# 10           1                     0.965083
# 11           1                     0.971969
# 12           2                     0.593801
# 13           2                     0.584471
# 14           2                     0.533248
# 15           1                     0.576164
# 16           1                     0.596130
# 17           1                     0.607547
# 18           1                     0.995373
# 19           1                     0.995381
# 20           1                     0.986007
# 21           2                     0.516045
# 22           2                     0.499839
# 23           2                     0.495158

# %%
print_run_ids(best_run_names_MLP)
# Out:
# - srbvb01a
# - oekx63p8
# - alprfdqq
# - d8w94wnf
# - 76lre0vu
# - 4z1wjp9y
# - kyc5dopk
# - x3nb16bc
# - c9xudzv0
# - mp8v0qtq
# - 7oe60sig
# - ccl9a7eu
# - rc1n4qi1
# - invvzj6h
# - 2fqxsay5
# - hpty0m0z
# - vqc4hdpr
# - 3ocbbqie
# - nc206z8l
# - hii8gyar
# - 013sp4et
# - j7trhmgk
# - l8anh9u4
# - sr87k9n5

# %% [markdown]
# # F-Act

# %%
fact_sweep_ids = [
    # 'bga4xu49', # everything
    # '7i2o46ri', # everything no dropout
    # '4p4opie9', # mice_protein and madelon no dropout
    # 'uw1zvim4', # more PBMC
    # 'hfqtys2c', # mice_protein and madelon no dropout more patience
    # 'yg8ursys', # PBMC re-tune
    # 'jyjjfywo', # mice protein re-tune
    'unbglcvv', # isolet & madelon re-tune
]

fact_hyperparameters = ['lr', 'num_hidden', 'sparsity_regularizer_hyperparam', 'dropout']

# %%
runs_data_fact = fetch_runs(entity, project, fact_sweep_ids)

# %%
best_run_names_fact = get_best_runs(runs_data_fact, fact_hyperparameters)
best_run_names_fact
# Out:
#    dataset  run_name  seed  sweep_id      lr  num_hidden  \
# 0   Isolet  q2wg1e7d     4  unbglcvv  0.0001           2
# 1   Isolet  9ngmtkt4     3  unbglcvv  0.0001           2
# 2   Isolet  ii40dhvs     2  unbglcvv  0.0001           2
# 3   Isolet  kohfnyvq     1  unbglcvv  0.0001           2
# 4   Isolet  ekjhciat     0  unbglcvv  0.0001           2
# 5  madelon  a6xkz2n4     4  unbglcvv  0.0030           2
# 6  madelon  xsuh1wsn     3  unbglcvv  0.0030           2
# 7  madelon  d54c6rrr     2  unbglcvv  0.0030           2
# 8  madelon  fao665k1     1  unbglcvv  0.0030           2
# 9  madelon  1s0mj012     0  unbglcvv  0.0030           2
#
#    sparsity_regularizer_hyperparam  dropout  bestmodel_valid/F1_weighted  \
# 0                              1.0      0.2                     0.931839
# 1                              1.0      0.2                     0.913466
# 2                              1.0      0.2                     0.931110
# 3                              1.0      0.2                     0.938151
# 4                              1.0      0.2                     0.923602
# 5                              0.1      0.0                     0.686342
# 6                              0.1      0.0                     0.735826
# 7                              0.1      0.0                     0.668826
# 8                              0.1      0.0                     0.756391
# 9                              0.1      0.0                     0.700000
#
#    bestmodel_test/F1_weighted
# 0                    0.938865
# 1                    0.894357
# 2                    0.919899
# 3                    0.913909
# 4                    0.922986
# 5                    0.626835
# 6                    0.710700
# 7                    0.645856
# 8                    0.689280
# 9                    0.701675

# %%
best_run_names_fact['dropout'].unique()
# Out:
# array([0.])

# %%
# PBMC run ids

# 3e7c2ala
# 9qx2b2na

# %%
# mice protein run ids

# 5le875vr
# 6utw0s44
# r46u12zd

# %% [markdown]
# ### Runs to report:
#
# - bfi5l6qu
# - ihpfigr4
# - rhrqy9bb
# - sj64pl05
# - dtv0wjox
# - gp378vp4
# - vqcdnueq
# - b8nrupvc
# - rcacu3yt
# - swbk9dsz
# - sawnisk5
# - dqq6q5ej
# - 33iwvq59
# - ko5c4p3v
# - h4m5vvcm
# - zyuohsyk
#
#
#
# - 0msrkm0b
#
#
#
# - 3v8n9qe6
# - 3e4jm286
# - n0mcba2f
# - 94j8ch8b
# - qskac7qn

# %% [markdown]
# ## Without max filtering:

# %%
print_run_ids(best_run_names_fact)
# Out:
# - bfi5l6qu
# - ihpfigr4
# - rhrqy9bb
# - sj64pl05
# - dtv0wjox
# - gp378vp4
# - vqcdnueq
# - b8nrupvc
# - rcacu3yt
# - swbk9dsz
# - sawnisk5
# - dqq6q5ej
# - 33iwvq59
# - ko5c4p3v
# - h4m5vvcm
# - zyuohsyk
# - nh4kxwyz
# - toim1dzn
# - cjaj7kri
# - 0msrkm0b
# - 9cot8lqv
# - ooqtpbvl
# - wb2t18o7
# - 3v8n9qe6
# - 3e4jm286
# - n0mcba2f
# - 94j8ch8b
# - qskac7qn

# %% [markdown]
# ## With max filtering:

# %%
runs_data_fact = fetch_runs(entity, project, fact_sweep_ids)
best_run_names_fact = get_best_runs(runs_data_fact, fact_hyperparameters)

# %%
best_run_names_fact
# Out:
#                              dataset  run_name  seed  sweep_id      lr  \
# 0                             COIL20  bfi5l6qu     2  bga4xu49  0.0010
# 1                             COIL20  ihpfigr4     1  bga4xu49  0.0010
# 2                             COIL20  rhrqy9bb     0  bga4xu49  0.0010
# 3                             Isolet  sj64pl05     2  bga4xu49  0.0003
# 4                             Isolet  dtv0wjox     1  bga4xu49  0.0003
# 5                             Isolet  gp378vp4     0  bga4xu49  0.0003
# 6                               PBMC  vqcdnueq     2  bga4xu49  0.0001
# 7                               USPS  b8nrupvc     2  bga4xu49  0.0010
# 8                               USPS  rcacu3yt     1  bga4xu49  0.0010
# 9                               USPS  swbk9dsz     0  bga4xu49  0.0010
# 10                           finance  sawnisk5     2  bga4xu49  0.0003
# 11                           finance  dqq6q5ej     1  bga4xu49  0.0003
# 12                           finance  33iwvq59     0  bga4xu49  0.0003
# 13                           madelon  ko5c4p3v     2  7i2o46ri  0.0030
# 14                           madelon  h4m5vvcm     1  7i2o46ri  0.0030
# 15                           madelon  zyuohsyk     0  7i2o46ri  0.0030
# 16                      mice_protein  oiugg9ff     2  hfqtys2c  0.0010
# 17                      mice_protein  50rib385     1  hfqtys2c  0.0010
# 18                      mice_protein  ve69xu11     0  hfqtys2c  0.0010
# 25  poly_binarised_decimalised_synth  n0mcba2f     2  bga4xu49  0.0003
# 26  poly_binarised_decimalised_synth  94j8ch8b     1  bga4xu49  0.0003
# 27  poly_binarised_decimalised_synth  qskac7qn     0  bga4xu49  0.0003
#
#     num_hidden  sparsity_regularizer_hyperparam  dropout  \
# 0            1                              0.0      0.2
# 1            1                              0.0      0.2
# 2            1                              0.0      0.2
# 3            1                              0.1      0.2
# 4            1                              0.1      0.2
# 5            1                              0.1      0.2
# 6            4                             10.0      0.2
# 7            1                              0.1      0.2
# 8            1                              0.1      0.2
# 9            1                              0.1      0.2
# 10           1                              0.1      0.2
# 11           1                              0.1      0.2
# 12           1                              0.1      0.2
# 13           4                              0.1      0.0
# 14           4                              0.1      0.0
# 15           4                              0.1      0.0
# 16           4                              0.5      0.0
# 17           4                              0.5      0.0
# 18           4                              0.5      0.0
# 25           1                              1.0      0.2
# 26           1                              1.0      0.2
# 27           1                              1.0      0.2
#
#     bestmodel_valid/F1_weighted
# 0                      0.985809
# 1                      0.992920
# 2                      1.000000
# 3                      0.921679
# 4                      0.932089
# 5                      0.925571
# 6                      0.846068
# 7                      0.965020
# 8                      0.971490
# 9                      0.967743
# 10                     0.593751
# 11                     0.604641
# 12                     0.599111
# 13                     0.738427
# 14                     0.747740
# 15                     0.699996
# 16                     0.967064
# 17                     0.962957
# 18                     0.958328
# 25                     0.256726
# 26                     0.284176
# 27                     0.280263

# %%
best_run_names_fact_to_run = best_run_names_fact[(best_run_names_fact['dataset'] != 'madelon') & (best_run_names_fact['dataset'] != 'mice_protein') ]

# %%
print_run_ids(best_run_names_fact_to_run)
# Out:
# - bfi5l6qu
# - ihpfigr4
# - rhrqy9bb
# - sj64pl05
# - dtv0wjox
# - gp378vp4
# - vqcdnueq
# - b8nrupvc
# - rcacu3yt
# - swbk9dsz
# - sawnisk5
# - dqq6q5ej
# - 33iwvq59
# - n0mcba2f
# - 94j8ch8b
# - qskac7qn

# %%
print_run_ids(best_run_names_fact)
# Out:
# - bfi5l6qu
# - ihpfigr4
# - rhrqy9bb
# - sj64pl05
# - dtv0wjox
# - gp378vp4
# - vqcdnueq
# - b8nrupvc
# - rcacu3yt
# - swbk9dsz
# - sawnisk5
# - dqq6q5ej
# - 33iwvq59
# - ko5c4p3v
# - h4m5vvcm
# - zyuohsyk
# - uua9jral
# - 4engzvgx
# - 5pb7hj4h
# - n0mcba2f
# - 94j8ch8b
# - qskac7qn

# %% [markdown]
# ## F-Act identifying PBMC to run
# Not all the PBMC runs finished successfully. We need to identify which runs to re-do so that we can get statistical significance.

# %%
wumwum = pd.DataFrame(runs_data_fact)

# %%
wumwum = wumwum[wumwum['dataset'] == 'PBMC']

# %%
grouped = wumwum.groupby(['lr', 'num_hidden', 'sparsity_regularizer_hyperparam'])

# Calculating the mean of 'model_valid/F1_weighted' and counting the number of rows for each group
result = grouped['bestmodel_valid/F1_weighted'].agg(['mean', 'count'])
result
# Out:
#                                                        mean  count
# lr     num_hidden sparsity_regularizer_hyperparam
# 0.0001 1          0.0                              0.806942      1
#                   0.1                              0.829282      2
#                   1.0                              0.817140      2
#                   10.0                             0.821775      2
#                   100.0                            0.807054      2
#        2          0.0                              0.829243      2
#                   0.1                              0.826875      2
#                   0.5                              0.819522      2
#                   1.0                              0.836508      1
#                   10.0                             0.821743      2
#                   100.0                            0.819027      2
#        4          0.0                              0.845983      1
#                   0.1                              0.845983      1
#                   0.5                              0.836357      1
#                   1.0                              0.841218      1
#                   10.0                             0.846068      1
#                   100.0                            0.811643      2
# 0.0003 1          0.0                              0.826441      1
#                   0.1                              0.821525      1
#                   0.5                              0.806936      2
#                   1.0                              0.811764      2
#                   10.0                             0.811757      2
#                   100.0                            0.802432      1
#        2          0.0                              0.813789      3
#                   0.1                              0.803933      3
#                   0.5                              0.816825      3
#                   1.0                              0.808801      3
#                   10.0                             0.813674      3
#                   100.0                            0.794588      2
#        4          0.0                              0.824909      3
#                   0.1                              0.824909      3
#                   0.5                              0.824900      3
#                   1.0                              0.823263      3
#                   10.0                             0.807232      3
#                   100.0                            0.800231      3
# 0.0010 1          0.0                              0.788462      1
#                   0.1                              0.802433      1
#                   0.5                              0.735485      1
#                   1.0                              0.802871      1
#                   100.0                            0.778641      2
#        2          0.0                              0.744986      1
#                   0.1                              0.770242      2
#                   0.5                              0.776113      2
#                   100.0                            0.797965      1
#        4          0.0                              0.764268      2
#                   0.1                              0.807336      1
#                   1.0                              0.729720      1
#                   10.0                             0.805921      3
#                   100.0                            0.730106      3

# %% [markdown]
# # SEFS

# %%
SEFS_sweep_ids = [
    'n6zb5lc9', # everything
]

SEFS_hyperparameters = ['lr', 'num_hidden']

# %%
runs_data_SEFS = fetch_runs(entity, project, SEFS_sweep_ids)
best_run_names_SEFS = get_best_runs(runs_data_SEFS, SEFS_hyperparameters)

# %%
best_run_names_SEFS
# Out:
#                              dataset  run_name  seed  sweep_id     lr  \
# 0                             COIL20  4ri15qxr     1  n6zb5lc9  0.003
# 1                             COIL20  8j0jc7hb     2  n6zb5lc9  0.003
# 2                             COIL20  n1h3md70     0  n6zb5lc9  0.003
# 3                             Isolet  5wir5gpp     2  n6zb5lc9  0.003
# 4                             Isolet  l7x9ro80     1  n6zb5lc9  0.003
# 5                             Isolet  cie5vyxw     0  n6zb5lc9  0.003
# 6                               USPS  7r7np8yl     2  n6zb5lc9  0.003
# 7                               USPS  p8m4bjsz     1  n6zb5lc9  0.003
# 8                               USPS  m30x375m     0  n6zb5lc9  0.003
# 9                            finance  q23bgu6e     2  n6zb5lc9  0.003
# 10                           finance  oomxlr29     1  n6zb5lc9  0.003
# 11                           finance  a3oi8xgt     0  n6zb5lc9  0.003
# 12                           madelon  nii841im     2  n6zb5lc9  0.003
# 13                           madelon  h9kiqdnu     1  n6zb5lc9  0.003
# 14                           madelon  y5o7lz1z     0  n6zb5lc9  0.003
# 15                      mice_protein  lo2blgf6     2  n6zb5lc9  0.003
# 16                      mice_protein  77wuap81     1  n6zb5lc9  0.003
# 17                      mice_protein  cuvpz3wf     0  n6zb5lc9  0.003
# 18  poly_binarised_decimalised_synth  6rd3gkh9     0  n6zb5lc9  0.003
# 19  poly_binarised_decimalised_synth  gjwugdf5     2  n6zb5lc9  0.003
# 20  poly_binarised_decimalised_synth  zbey3upy     1  n6zb5lc9  0.003
#
#     num_hidden  bestmodel_valid/F1_weighted
# 0            1                     0.961426
# 1            1                     0.971665
# 2            1                     0.957945
# 3            1                     0.900668
# 4            1                     0.867696
# 5            1                     0.878427
# 6            1                     0.936241
# 7            1                     0.933000
# 8            1                     0.937953
# 9            2                     0.565059
# 10           2                     0.588798
# 11           2                     0.586895
# 12           2                     0.639728
# 13           2                     0.632463
# 14           2                     0.653822
# 15           1                     0.848273
# 16           1                     0.857545
# 17           1                     0.874817
# 18           1                     0.357014
# 19           1                     0.348194
# 20           1                     0.383270

# %%
print_run_ids(best_run_names_SEFS)
# Out:
# - 4ri15qxr
# - 8j0jc7hb
# - n1h3md70
# - 5wir5gpp
# - l7x9ro80
# - cie5vyxw
# - 7r7np8yl
# - p8m4bjsz
# - m30x375m
# - q23bgu6e
# - oomxlr29
# - a3oi8xgt
# - nii841im
# - h9kiqdnu
# - y5o7lz1z
# - lo2blgf6
# - 77wuap81
# - cuvpz3wf
# - 6rd3gkh9
# - gjwugdf5
# - zbey3upy

# %% [markdown]
# # CAE

# %%
cae_sweep_ids = [
    'h245pc2i', 
    'jqulrkke', # finance
    'xh18ha0v', # PBMC
]

cae_hyperparameters = ['CAE_neurons_ratio']

# %%
runs_data_cae = fetch_runs(entity, project, cae_sweep_ids)
best_run_names_cae = get_best_runs(runs_data_cae, cae_hyperparameters)

# %%
best_run_names_cae
# Out:
#                              dataset  run_name  seed  sweep_id  \
# 0                             COIL20  ii9u6l2d     2  h245pc2i
# 1                             COIL20  5exrw8f4     1  h245pc2i
# 2                             COIL20  tj64tq2g     0  h245pc2i
# 3                             Isolet  mlc47s7c     2  h245pc2i
# 4                             Isolet  b9ho9xwr     1  h245pc2i
# 5                             Isolet  vwt0ppjl     0  h245pc2i
# 6                               PBMC  dkl0yc56     1  xh18ha0v
# 7                               PBMC  5pvh1fpu     2  xh18ha0v
# 8                               PBMC  qic5h6a4     2  xh18ha0v
# 9                               PBMC  b3a2ob4c     0  xh18ha0v
# 10                              PBMC  mori0hae     1  xh18ha0v
# 11                              PBMC  8p5sr93k     0  xh18ha0v
# 12                              PBMC  g92z1gfj     2  xh18ha0v
# 13                              PBMC  zfpn7ire     0  xh18ha0v
# 14                              USPS  xp5qd1o8     2  h245pc2i
# 15                              USPS  0gxjfvc4     1  h245pc2i
# 16                              USPS  100tdx2j     0  h245pc2i
# 17                           finance  locgod8m     2  jqulrkke
# 18                           finance  8fxmab8q     1  jqulrkke
# 19                           finance  qofyg26n     0  jqulrkke
# 20                           madelon  ym9c79tk     2  h245pc2i
# 21                           madelon  axbbimg7     1  h245pc2i
# 22                           madelon  y2i3p5mk     0  h245pc2i
# 23                      mice_protein  7hn6dy78     2  h245pc2i
# 24                      mice_protein  7luthcz4     1  h245pc2i
# 25                      mice_protein  rgpplyo8     0  h245pc2i
# 26  poly_binarised_decimalised_synth  hghw5y17     2  h245pc2i
# 27  poly_binarised_decimalised_synth  quxcxwcf     1  h245pc2i
# 28  poly_binarised_decimalised_synth  1srt26yx     0  h245pc2i
#
#     CAE_neurons_ratio  bestmodel_valid/F1_weighted
# 0                 1.0                     0.971864
# 1                 1.0                     0.989278
# 2                 1.0                     0.989575
# 3                 0.8                     0.827761
# 4                 0.8                     0.845743
# 5                 0.8                     0.810576
# 6                 0.1                     0.677145
# 7                 0.1                     0.715063
# 8                 0.1                     0.675973
# 9                 0.1                     0.653782
# 10                0.1                     0.558728
# 11                0.1                     0.685646
# 12                0.1                     0.747900
# 13                0.1                     0.624583
# 14                1.0                     0.899623
# 15                1.0                     0.900220
# 16                1.0                     0.914648
# 17                0.7                     0.619210
# 18                0.7                     0.606795
# 19                0.7                     0.608456
# 20                1.0                     0.723073
# 21                1.0                     0.741201
# 22                1.0                     0.716930
# 23                0.6                     0.962966
# 24                0.6                     0.847084
# 25                0.6                     0.874178
# 26                0.8                     0.381273
# 27                0.8                     0.450696
# 28                0.8                     0.426882

# %%
print_run_ids(best_run_names_cae)
# Out:
# - ii9u6l2d
# - 5exrw8f4
# - tj64tq2g
# - mlc47s7c
# - b9ho9xwr
# - vwt0ppjl
# - dkl0yc56
# - 5pvh1fpu
# - qic5h6a4
# - b3a2ob4c
# - mori0hae
# - 8p5sr93k
# - g92z1gfj
# - zfpn7ire
# - xp5qd1o8
# - 0gxjfvc4
# - 100tdx2j
# - locgod8m
# - 8fxmab8q
# - qofyg26n
# - ym9c79tk
# - axbbimg7
# - y2i3p5mk
# - 7hn6dy78
# - 7luthcz4
# - rgpplyo8
# - hghw5y17
# - quxcxwcf
# - 1srt26yx

# %% [markdown]
# # SCAE

# %%
scae_sweep_ids = [
    '8yghctpp', 
    'xclyvl0c', # finance
    'vle39arl', # PBMC
]

scae_hyperparameters = ['CAE_neurons_ratio']

# %%
runs_data_scae = fetch_runs(entity, project, scae_sweep_ids)
best_run_names_scae = get_best_runs(runs_data_scae, scae_hyperparameters)

# %%
best_run_names_scae
# Out:
#                              dataset  run_name  seed  sweep_id  \
# 0                             COIL20  21jdujes     2  8yghctpp
# 1                             COIL20  qqbg2iq3     1  8yghctpp
# 2                             COIL20  bjc7m645     0  8yghctpp
# 3                             Isolet  wlj7x2jf     2  8yghctpp
# 4                             Isolet  a6b98dl6     1  8yghctpp
# 5                             Isolet  sfl616uk     0  8yghctpp
# 6                               PBMC  c1kwap92     0  vle39arl
# 7                               USPS  ots2ntku     2  8yghctpp
# 8                               USPS  3rk3gfzz     1  8yghctpp
# 9                               USPS  h9y8om3n     0  8yghctpp
# 10                           finance  bwqg5821     1  xclyvl0c
# 11                           finance  f9o7xfr2     2  xclyvl0c
# 12                           finance  w9qbjd86     0  xclyvl0c
# 13                           madelon  97tanv0l     2  8yghctpp
# 14                           madelon  g38qapgd     1  8yghctpp
# 15                           madelon  n0fre6ie     0  8yghctpp
# 16                      mice_protein  9zh6l5b6     2  8yghctpp
# 17                      mice_protein  nek2payn     1  8yghctpp
# 18                      mice_protein  7kg0lhd3     0  8yghctpp
# 19  poly_binarised_decimalised_synth  5cz3yfw4     2  8yghctpp
# 20  poly_binarised_decimalised_synth  yz7ijx4r     1  8yghctpp
# 21  poly_binarised_decimalised_synth  dciqkh40     0  8yghctpp
#
#     CAE_neurons_ratio  bestmodel_valid/F1_weighted
# 0                 0.1                     0.048068
# 1                 0.1                     0.030209
# 2                 0.1                     0.098516
# 3                 0.2                     0.049223
# 4                 0.2                     0.023762
# 5                 0.2                     0.046294
# 6                 0.1                     0.832341
# 7                 0.1                     0.228966
# 8                 0.1                     0.184663
# 9                 0.1                     0.223812
# 10                0.6                     0.514551
# 11                0.6                     0.564343
# 12                0.6                     0.562524
# 13                1.0                     0.619141
# 14                1.0                     0.634567
# 15                1.0                     0.619208
# 16                1.0                     0.107147
# 17                1.0                     0.222228
# 18                1.0                     0.173222
# 19                0.3                     0.360959
# 20                0.3                     0.361001
# 21                0.3                     0.384654

# %%
print_run_ids(best_run_names_scae)
# Out:
# - 21jdujes
# - qqbg2iq3
# - bjc7m645
# - wlj7x2jf
# - a6b98dl6
# - sfl616uk
# - c1kwap92
# - ots2ntku
# - 3rk3gfzz
# - h9y8om3n
# - bwqg5821
# - f9o7xfr2
# - w9qbjd86
# - 97tanv0l
# - g38qapgd
# - n0fre6ie
# - 9zh6l5b6
# - nek2payn
# - 7kg0lhd3
# - 5cz3yfw4
# - yz7ijx4r
# - dciqkh40
